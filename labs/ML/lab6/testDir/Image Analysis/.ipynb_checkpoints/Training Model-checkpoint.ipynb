# %%
import pandas as pd
df=pd.read_csv("rice.csv")
df
# Out:
#          Area   Perimeter  Major Axis Length  Minor Axis Length  Eccentricity  \
# 0      7812.0  376.936073         149.842865          69.578377      0.885656
# 1      6040.5  327.521859         134.659363          59.383949      0.897510
# 2      6829.5  331.119838         122.208038          72.217400      0.806717
# 3      7728.5  368.090401         141.731461          70.788162      0.866341
# 4      7789.5  364.835569         145.944336          72.810875      0.866663
# ...       ...         ...                ...                ...           ...
# 74995  6174.5  309.806130         108.644669          73.536964      0.736114
# 74996  5676.0  295.563488         107.199905          67.357109      0.777945
# 74997  6216.5  314.835567         105.423271          76.913910      0.683904
# 74998  5718.0  306.391916         113.915695          63.878529      0.827983
# 74999  6377.0  313.764499         110.466736          74.524582      0.738153
#
#        Convex Area    Extent  Aspect Ratio  Compactness  Roundness      class
# 0           8004.5  0.772166      2.253731    18.187507   0.690934    arborio
# 1           6183.0  0.679318      1.539474    17.758558   0.707623    arborio
# 2           6959.0  0.663703      0.933333    16.053935   0.782760    arborio
# 3           7942.0  0.618280      1.250000    17.531286   0.716797    arborio
# 4           7901.5  0.772768      2.057143    17.087745   0.735402    arborio
# ...            ...       ...           ...          ...        ...        ...
# 74995       6292.5  0.699343      1.345679    15.544552   0.808410  karacadag
# 74996       5751.0  0.687500      0.895833    15.390729   0.816490  karacadag
# 74997       6389.0  0.710620      0.750000    15.944894   0.788113  karacadag
# 74998       5812.5  0.648299      1.088889    16.417630   0.765419  karacadag
# 74999       6472.0  0.762799      0.690909    15.438005   0.813989  karacadag
#
# [75000 rows x 11 columns]

# %%
x=df.drop(columns=['class'])
y=df['class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(x_train)
X_test=sc.transform(x_test)

# %% [markdown]
# LOGISTIC REGRESSION MODEL REFERENCE:-https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
classifier = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, tol=1e-4)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000, random_state=0)

# %% [markdown]
# DECISION TREE MODEL

# %%
from sklearn.tree import DecisionTreeClassifier
tree_model=DecisionTreeClassifier(random_state=0)
tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# SVM MODEL

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='rbf', random_state=0)
svm_model.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %% [markdown]
# GUASSIAN MODEL

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# MODEL PREDICTION

# %%
classifierPrediction=classifier.predict(X_test) #Logistic regression Model
tree_modelPrediction=tree_model.predict(X_test) #Decision tree Model
svm_modelPrediction=svm_model.predict(X_test) #SVM Model
gnbPrediction=gnb.predict(X_test) #Gaussian Model

# %% [markdown]
# PERFORMANCE REPORT

# %%
#LOGISTIC REGRESSION MODEL
from sklearn.metrics import classification_report
print(classification_report(classifierPrediction,y_test))
# Out:
#               precision    recall  f1-score   support
#
#      arborio       0.96      0.96      0.96      2928
#      basmati       0.96      0.98      0.97      2910
#       ipsala       0.99      1.00      1.00      3046
#      jasmine       0.97      0.96      0.96      3069
#    karacadag       0.97      0.97      0.97      3047
#
#     accuracy                           0.97     15000
#    macro avg       0.97      0.97      0.97     15000
# weighted avg       0.97      0.97      0.97     15000

# %%
#DECISION TREE MODEL
from sklearn.metrics import classification_report
print(classification_report(tree_modelPrediction,y_test))
# Out:
#               precision    recall  f1-score   support
#
#      arborio       0.95      0.95      0.95      2935
#      basmati       0.97      0.97      0.97      2979
#       ipsala       1.00      0.99      0.99      3061
#      jasmine       0.96      0.97      0.96      2994
#    karacadag       0.96      0.96      0.96      3031
#
#     accuracy                           0.97     15000
#    macro avg       0.97      0.97      0.97     15000
# weighted avg       0.97      0.97      0.97     15000

# %%
#SVM MODEL
from sklearn.metrics import classification_report
print(classification_report(svm_modelPrediction,y_test))
# Out:
#               precision    recall  f1-score   support
#
#      arborio       0.96      0.97      0.97      2908
#      basmati       0.98      0.98      0.98      2948
#       ipsala       0.99      1.00      1.00      3041
#      jasmine       0.98      0.97      0.97      3040
#    karacadag       0.98      0.97      0.97      3063
#
#     accuracy                           0.98     15000
#    macro avg       0.98      0.98      0.98     15000
# weighted avg       0.98      0.98      0.98     15000

# %%
#GUASSIAN BAYES THEOREM MODEL
from sklearn.metrics import classification_report
print(classification_report(gnbPrediction,y_test))
# Out:
#               precision    recall  f1-score   support
#
#      arborio       0.96      0.97      0.97      2914
#      basmati       0.95      0.98      0.97      2881
#       ipsala       0.99      1.00      0.99      3031
#      jasmine       0.98      0.95      0.96      3121
#    karacadag       0.97      0.97      0.97      3053
#
#     accuracy                           0.97     15000
#    macro avg       0.97      0.97      0.97     15000
# weighted avg       0.97      0.97      0.97     15000

# %%
categories = ["arborio", "basmati", "ipsala", "jasmine", "karacadag"]

# %%
#CONFUSION MATRIX OF LOGISTIC REGRESSION
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(classifierPrediction,y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#CONFUSION MATRIX OF DECISION TREE MODEL
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(tree_modelPrediction,y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#CONFUSION MATRIX OF SVM MODEL
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(svm_modelPrediction,y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#CONFUSION MATRIX OF SVM MODEL
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(gnbPrediction,y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
import joblib
joblib.dump(classifier, "logistic_model.pkl")
joblib.dump(tree_model, "Decision_Tree_model.pkl")
joblib.dump(svm_model, "SVM_model.pkl")
joblib.dump(gnb, "Gaussian_model.pkl")
# Out:
# ['Gaussian_model.pkl']
